# %% [markdown]
# 학습목표
# - 현실 세계 문제를 그래프로 추상화해서 해결하는 방법을 학습한다.
# - 그래프 탐색 기범인 BFS와 DFS에 대해 학습한다.
# - 그래프 앍리즘에 활용되는 상호 배타 집합(Disjoint Set)의 자료구조에 대해 학습한다.

# %% [markdown]
# 그래프의 기본과 탐색

# %% [markdown]
# 그래프 기본

# %% [markdown]
# 그래프
# - 아이템(사물 또는 추상적 개념)들과 이들 사이의 연결 관계를 표현
# > 선형 자료구조나 트리 자료구조로 표현하기 어려운 N : N 관계를 원소들을 표현하기에 용이합니다.

# %% [markdown]
# 그래프
# - 정접(Vertex)들의 집합과 이들을 연결하는 간선(Edge)들의 집합으로 구성된 자료 구조
#   - V : 저점의 개수, E : 그래프에 포함된 간선의 개수라 할 때 V개의 정점을 가지는 그래프는 최대 E = V * (V - 1) / 2개의 간선을 가질 수 있습니다.

# %% [markdown]
# 그래프 유형
# - 무향(무방향) 그래프(Undirected Graph)
# - 유향(방향) 그래프(Directed Graph)
# - 가중치 그래프(Weighted Graph)
# - 사이클 없는 방향 그래프(DAG, Directed Acyclic Graph, 방향성 비순환 그래프)
# - 완전 그래프 : 정점들에 대해 가능한 모든 간선들을 가진 그래프
# - 부분 그래프 : 원래 그래프에서 일부의 정점이나 간선을 제외한 그래프

# %% [markdown]
# 인접 정점
# - 인접(Adjacency)
#   - 두 개의 정점에 간선이 존재(연결됨)하면 서로 인접 관계라고 합니다.
#   - 완전 그래프 속한 임의의 두 정점들은 모두 인접해 있습니다.

# %% [markdown]
# 그래프 경로
# - 경로란 간선들을 순서대로 나열한 것
# - 결오 중 한 정점을 최대한 한번만 지나는 경로를 단순경로라고 함
# - 시작한 정점에서 끝나는 경로를 사이클(Cycle)이라고 함

# %% [markdown]
# 그래프 표현
# - 간선의 정보를 저장하는 방식, 메모리나 성능을 고려해서 결정
# - 인접 행렬(Adjacent matrix)
#   - V x V 크기의 2차원 배열을 이용해서 간선 정보를 저장합니다.
# - 인접 리스트 (Adjacent List)
#   - 각 정점마다 해당 정점과 인접한 정점 정보를 저장
# - 간선의 배열
#   - 간선(시작 정범, 끝 정점)을 배열에 연속적으로 저장

# %% [markdown]
# 인접 행렬: 두 정점을 연결하는 간선의 유무를 행렬로 표현
# - V * V 정방 행렬
# - 행 번호와 열 번호는 그래프의 정점에 대응
# - 두 정점이 인접되어 있으면 1, 그렇지 않으면 0으로 표현
# - 무향 그래프
#   - i 번째 행의 합 = i 번째 열의 합 = Vi 의 차수
# - 유향 그래프
#   - 행 i 의 합 = Vi 의 진출 차수
#   - 열 i 의 합 = Vi 의 진입 차수
#
# 인접 행렬의 단점은?
#   - 정점 수에 비해 간선 수가 적은 경우 공간 낭비가 심함

# %% [markdown]
# 인접 리스트
# - 각 정점에 대한 인접 정점들을 순차적으로 표현
# - 하나의 정점에 대한 인접 정점들을 각각 노드로 연결 리스트로 저장

# %% [markdown]
# 무향 그래프의 인접 리스트
# > 인접 리스트의 노드 수 = 간선의 수 * 2
# > 각 정점의 노드 수 = 정점의 차수

# %% [markdown]
# 유향 그래프의 인접 리스트
# > 인접 리스트 노드 수 = 간선의 수
# > 각 정점의 노드 수 = 정점의 진출 차수

# %%
# 그래프를 표현하는 두 가지 방식

V, E = map(int, input().split())

# 인접 행렬 (0, 1로 연결 유무를 모두 저장)
# 노드의 수와 노드 번호에 따라 V or V + 1 잘 확인하기
graph = [[0] * V for _ in range(V)]
for _ in range(E):
    start, end = map(int, input().split())
    graph[start][end] = 1
    graph[end][start] = 1   # 양방향

for row in graph:
    print(row)

# 인접 리스트 (연결된 정보만 저장)
graph = [[] for _ in range(V)]
for _ in range(E):
    start, end = map(int, input().split())
    graph[start].append(end)
    graph[end].append(start)    # 양방향

for row in graph:
    print(row)

# %% [markdown]
# DFS

# %% [markdown]
# 그래프 완전 탐색
# - 특정 점점으로부터 갈 수 있는 노드들을 한 번씩 방문
#
# DFS (Depth First Search, 깊이 우선 탐색)
# - 개념 : 진행하는 방향으로 갈 수 있는 곳이 있으면 끝까지 이동
#   - 갈 수 있는 곳이 있다면 끝까지 이동하다가
#   - 더 이상 갈 수 없다면 (마지막 분기점에서 다시 이동)

# %% [markdown]
# 알고리즘 - 재귀
# G : 탐색할 그래프
# c : 방문하는 정점
# ```
# DFS_Recursive(G, v)
#
#     visited[v] <- True                  # v 방문 설정
#
#     FOR each all w in adjacency(G, v)   # v에 인접한 정점 w에 대해
#         IF visited[w] != True           # w에 방문한 적이 없으면
#             DFS_Recursive(G, w)
# ```

# %% [markdown]
# 알고리즘 - 반복
#
# ```
# STACK s         # 스택 생성
# visited[]       # 방분한 정점 표시
# DFS(v)
#     push(s, v)  # 시작정점
#     visited[v] = True
#     WHILE NOT isEmpty(s)
#         v <- pop(s)
#         visit(v)
#         FOR each w in adjacency(v)
#             IF NOT visited[w]
#                 push(s, w)
#                 visited[v] = True

# %% [markdown]
# BFS(Breadth First Search, 너비 우선 탐색)
# - 개념 : 인접한 노드들부터 먼저 방문하면서 가자

# %% [markdown]
# ```
# BFS(G, v) // 그래프 G, 탐색 시작점 v
#     큐 생성
#     시작점 v를 큐에 삽입
#     점 v를 인큐된 것으로 표시
#
#     WHILE 큐가 비어있지 않은 경우
#         t <- 큐의 첫번쨰 원소 반환
#
#         FOR t와 연결된 모든 선에 대해
#             u <- t의 인접점
#             u가 인큐되지 않은 곳이면,
#             u를 큐에 넣고, 인큐된 것으로 표시
# ```

# %% [markdown]
# Union-Find (Disjoint Set)

# %% [markdown]
# 서로소 집합(Disjoint Set)
# - 서로 공통 원소가 없는 집합
#   - 교집합이 없는 집합들 입니다.
# - 대표자(representative)
#   - 각 집합을 대표하는 하나의 원소를 말합니다.
# - 상호 배타 집합
#   - 확률, 논리, 집합론에서 동시에 일어날 수 없는 경우, 공통이 없는 경우를 말합니다.
#   - 집합론에서는 서로소와 같은 뜻으로 사용됩니다.
# - 표현 방법
#   - 연결리스트로 표현할 수 있습니다.
#   - 트리를 이용해 표현할 수 있습니다.

# %% [markdown]
# 서로소 집합 연산
# - Make-Set(x)
#   - x를 원소로 가진 집합을 만듭니다.
# - Find-Set(x)
#   - x가 속한 집합의 대표 원소를 반환합니다.
# - Union(x, y)
#   - y가 속한 집합과 x가 속한 집합의 합집합을 만듭니다.
#   - x가 합집합의 대표원소가 됩니다.

# %% [markdown]
# 상호 배타 집합 표현 - 연결리스트
# - 같은 집합의 원소들은 하나의 연결리스트로 관리
# - 연결리스트의 맨 앞의 원소가 집합의 대표 원소
# - 각 원소는 집합의 대표원소를 가리키는 링크를 가짐

# %% [markdown]
# 상호 배타 집합 표현 - 트리
# - 하나의 집합(a disjoint set)을 하나의 트리로 표현함
# - 자식 노드가 부모 노드를 가리키며 루트 노드가 대표자가 됨

# %% [markdown]
# 상호배타 집합을 표현한 트리의 배열을 이용한 저장

# %% [markdown]
# 상호 배타 집합에 대한 연산
# - Make-Set(x) : 유일한 멤버 x를 포함하는 새로운 집합을 생성하는 연산
# - Find_Set(x) : x를 포함하는 집합을 찾는 연산
# - Union(x, y) : x와 y를 포함하는 두 집합을 통합하는 연산

# %% [markdown]
# ```
# Make-Set(x)
#     p[x] <- x
#
# Find-Set(x)
#     IF x == p[x] : RETURN x
#     ELSE         : RETURN Find+Set(p[x])
#
# Union(x, y)
#     p[Find-Set(y)] <- Find-Set(x)
