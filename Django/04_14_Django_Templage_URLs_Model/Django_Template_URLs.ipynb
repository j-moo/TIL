# %% [markdown]
# Django Template system
# - 파이썬 데이터(context)를 HTML 문서 (Template)와 결합하여, 로직과 표현을 분리할 채 동적인 웹페이지를 생성하는 도구

# %% [markdown]
# HTML의 곤텐츠를 변수 값에 따라 변경하기

# %% [markdown]
# 2. Filter
# - 변수 + | + 필터명 (사이에 공백이 있으면 안됨)

# %% [markdown]
# 3. Tags
# - 반복 또는 논리를 수행하여 제어 흐름을 만듦
# - 일부 태그는 시작과 종료 태그가 필요
# - 약 24개의 built-in template tags를 제공

# %% [markdown]
# 'extends' tag
# - 자식 (하위) 템플릿이 부모 템플릿(공통 사용할 HTML)을 확장한다는 것을 알림

# %% [markdown]
# 데이터를 보내고 가져오기 (Sending and Retrieving form data)
# - HTML 'form'(사용자 입력을 묶어서 보내는 html form 태그) elemant를 통해
