# %% [markdown]
# 학습 목표
# - Django Model 클래스를 이용해 데이터베이스 테이블 구조를 설계하고 "설계도(blueprint)" 역할을 설명할 수 있다.
# - 다양한 Field type과 Field option을 지정해 컬럼의 데이터 유형과 제약 조건을 정의할 수 있다.
# - python manage.py makemigrations / magrate 두 단계로 모델 변경 사항을 안전하게 데이터 베이스에 반영할 수 있다.
# - admin.site.register()로 모델을 Django Admin에 등록하여 웹 UI에서 게시글을 생성, 조회, 수정, 삭제(CURD)할 수 있다.
# - Django 기본 DB 엔진인 SQLite의 특성과 db.sqlite3를 Git에서 제외해야 하는 이유를 설명할 수 있다.

# %% [markdown]
# Model
# - 데이터베이스와 Python 클래스(객체)로 추상화된 형태로 상호작용
# - Django의 강력한 기능: 개발자가 데이터베이스에 대한 깊은 지식 없이도 쉽게 데이터 관리 기능
# - 유지보수 및 확장성 증대 : 데이터베이스 변경 시에도 코드 수정 최소화, 재사용 가능한 데이터 모델을 통해 개발 효율성 향상

# %% [markdown]
# Model을 통한 DB(데이터베이스)관리
# - urls.py: 사용자 요청의 시작점
# - views.py: 요청을 처리하고 models.py를 통해 데이터를 다룸
# - models.py: 데이터베이스를 정의하고, 데이터베이스와 상호작용
# - templates: views.py로부터 받은 데이터를 사용자에게 보여줄 화면을 구성
#
# ![alt text](<화면 캡처 2026-04-18 011023.jpg>)

# %% [markdown]
# Model class
# - DB의 테이블을 정의하고 데이터를 조작할 수 있는 기능들을 제공
#
# > models.Model 상속받아서 DB를 정의
# > 상속받아서 데이터 조작 할 수 있다
# > Model class는 데이터베이스 테이블의 구조를 설계하는 '청사진'역할을 합니다.
# > 어떤 데이터(컬럼)를 저장할지, 그 데이터의 형태는 어떠할지(타입, 길이 등)를 Python 코드로 명확히 정의합니다.

# %% [markdown]
# Model 클래스 작성
#
# - articles 앱의 models.py에 위 코드를 작성합니다.
#
# ![alt text](<화면 캡처 2026-04-18 011435.jpg>)

# %% [markdown]
# Model 클래스 살펴보기
# - 작성한 모델 클래스는 최종적으로 DB에 다음과 같은 테이블 구조를 만듦
#
# ![alt text](<화면 캡처 2026-04-18 011608.jpg>)
#
# - django.db.models 모듈의 Model이라는 부모 클래스를 상속받음
# - Model Field
#   - 데이터베이스 테이블의 열(column)을 나타내는 중요한 구성 요소
#   - '데이터의 유형' 과 '제약 조건'을 정의
#
#
# SQLite
# 1. 파일로 관리 (설치 x)
# 2.

# %% [markdown]
# Model Field
# - DB 테이블의 필드(열) 정의 데이터 타입(Field types) 및 제약 조건 명시

# %% [markdown]
# 제약 조건 (Constraint)
# - 특정 규칙을 강제하기 위해 테이블의 열이나 행에 적용되는 규칙이나 제한사항

# %% [markdown]
# 주요 필드 옵션
# - null
# - blank
# - default

# %% [markdown]
# Migrations
