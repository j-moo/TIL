# %% [markdown]
# # Start 강의 정리 (자료: start_2)
#
# 👋 *요약에 ‘…’(생략)이 보이지 않도록, 핵심 문장은 가능한 한 **문장 그대로** 가져오고, 긴 내용은 <details>로 접어뒀어요.*

# %% [markdown]
# ## 1. 제목/메타
#
# ### 🎯 목표
# - 강의 핵심 개념을 **한눈에 구조화**
# - 실전 문제풀이에서 필요한 **검증(엣지/복잡도) 루틴** 만들기
# - 코드는 **원본 유지**, 필요 시 예시 실행으로 보강
#
# ### 🔑 키워드
# `문제해결` `검증` `엣지케이스` `시간복잡도` `자료구조` `알고리즘` `진법/비트` `입출력`
#
# ### ⭐ 중요도
# - 원문에 **중요/평가/검증** 표시가 있으면 카드에서 굵게 잡아둘게요.
#
# ### 🗂️ 목차
# 1) 제목/메타
# 2) 핵심 개념
# 3) 개념정리(가독성 강화)
# 4) 풀이 전략
# 6) 구현
# 7) 테스트 + 자주하는 실수
# 8) 복잡도
# 9) 요약 + 미니 퀴즈

# %% [markdown]
# ## 2. 핵심 개념
#
# 아래 항목들만 먼저 잡고 들어가면 전체 흐름이 빨리 잡혀요 😊
#
# - **진법/비트/입출력**
# - **10 진수 -> 2 진수로 변환 구현**
# - **2 진수를 10 진수로 변환**
# - **파이썬 구현**
# - **신기한 XOR**
# - **암호화에 사용되는 XOR**
# - **쉬프트 연산자**
# - **음수 표현 방법**
# - **2의 보수 예시**
# - **신기한 2의 보수**
# - **파이썬에서 실수 출력 방법**
# - **소수점 출력 방법**
# - **파이썬에서의 실수 표현 범위**
# - **컴퓨터는 실수를 내부적으로 근사적을으로 관리**

# %% [markdown]
# ## 3. 개념정리(가독성 강화 버전)
#
# ### A) 한눈에 보기 표 🗺️
#
# | 개념 | 한줄 정의 | 핵심 키워드 | 자주 나오는 포인트 |
# |---|---|---|---|
# | 진법/비트/입출력 | 10진수 -> 다른 진수로 변환 - 원하는 다른 진법의 수로 나눈 뒤 나머지를 거꾸로 읽음 ![alt text](data:image/png;base64,...) 16진수와 2진수 변환 - 2진수, 10진수간 변환은 연산이 많으나, 2진수, 16진수간 변환은 연산이 없음 - 진법 변환을 빠르게 할 수 있으려면 우측 진수 표를 암기하는 것을 권장함 ![alt text](data:image/png;base64,...) 16진수 0xF9를 2진수로 변환해보기 - 정답 = 1111 1001 16진수 0xBB3를 2진수로 변환해보기 - 정답 = 1011 1011 0011 2진수 1100101111를 16진수로 변환해보기 - 먼저 네 자리씩 끊어주기 - 11 0010 1111 - 정답 : 0x32F 비트와 바이트 - 1 bit : 0 과 1을 표현하는 정보의 단위 - 1 byte : 8-bit를 묶어 1 Byte라고 함 (메모리 주소가 부여되는 단위) - 예시 - 1001011011011100 은 총 몇 비트이면서, 몇 바이트 인가? | 비트, 연산, alt, text, data, image | 진법 |
# | 10 진수 -> 2 진수로 변환 구현 | 10 진수 -> 2 진수로 변환 구현 - 10진수를 지속적으로 2로 나누어 구현 - 마지막으로 List를 거꾸로 뒤집기 | 구현, 진수, 진수로, 변환, 10진수를, 지속적으로 |  |
# | 2 진수를 10 진수로 변환 | 2 진수를 10 진수로 변환 ![alt text](data:image/png;base64,...) | Hee, eg, Hrr7, j7, H4, 진수를 |  |
# | 파이썬 구현 | 파이썬 구현 - 7 & 5 -> 이진수로 표현하면 0b11 & 0b101 ![alt text](data:image/png;base64,...) | bdd1, O9, 9re, POf, Pz, 파이썬 |  |
# | 신기한 XOR | 신기한 XOR - 어떤 값이던 특정 수로 2회 XOR를 하면 원래 수로 돌아옴 | 수로, 신기한, XOR, 어떤, 값이던, 특정 |  |
# | 암호화에 사용되는 XOR | 암호화에 사용되는 XOR - 친구 1과 친구2는 서로 비밀코드를 1004로 약속 ![alt text](data:image/png;base64,...) | Hw, P1, n4, H5, c9, fz |  |
# | 쉬프트 연산자 | 쉬프트 연산자 - Left Shift << : 특정 수 만큼 비트를 왼쪽으로 밀어냄 - Right Shift >> : 특정 수 만큼 비트를 오른쪽으로 밀어냄 (우측 비트들이 제거됨) ![alt text](data:image/png;base64,...) | Pz, v7, 9e, Shift, 특정, 만큼 | 비트 |
# | 음수 표현 방법 | 음수 표현 방법 - 컴퓨터는 음수를 "2의 보수"로 관리함 맨 앞자리 - 맨 앞자리 bit(MSB)는 음수 or 양수를 구분하는 비트임 - 2의 보수: 각 비트를 뒤집는다 -> +1을 진행 - 컴퓨터가 2의 보수를 사용하여 음수를 관리하는 이유 - 뺄셈의 연산 속도를 올릴 수 있으며, +0과 -0을 따로 취급하지 않기 위해 사용합니다. | 2의, 음수, 음수를, 보수, 앞자리, 표현 | 비트 |
# | 2의 보수 예시 | 2의 보수 예시 - 10001의 2의 보수 - 수를 모두 뒤집고 1을 더합니다 | 2의, 보수, 수를, 1을, 더합니다, 예시 |  |
# | 신기한 2의 보수 | 신기한 2의 보수 - 2의 보수를 취한 수를, 한번 더 2의 보수를 취하면 윈래의 값으로 돌아옴 - 10001의 2의 보수 - 수를 모두 뒤집고 1을 더합니다 | 2의, 보수, 수를, 1을, 5를, x5 |  |
# | 파이썬에서 실수 출력 방법 | 파이썬에서 실수 출력 방법 - 파이썬은 f-string 문법을 지향 | 파이썬에서, 실수, 출력, 파이썬은, string, 문법을 |  |
# | 소수점 출력 방법 | 소수점 출력 방법 - {t2:.2f} : t2값을 소수점 셋째자리에서 반올림하여 표현 | 소수점, 출력, t2, 2f, t2값을, 셋째자리에서 |  |
# | 파이썬에서의 실수 표현 범위 | 파이썬에서의 실수 표현 범위 - 파이썬에서는 64비트 부동소수점으로 실수를 표현함 - 15~17자리 정밀도와 +- 1.8e308 범위를 갖습니다 | 표현, 표현할, 있는, 값은, 파이썬에서의, 실수 | 비트 |
# | 컴퓨터는 실수를 내부적으로 근사적을으로 관리 | 컴퓨터는 실수를 내부적으로 근사적을으로 관리 - 실수는 정확한 값이 아니라 근사 값으로 저장되는데 이때 생기는 작은 오차가 계산 과정에서 다른 결과를 가져옴 ![alt text](data:image/png;base64,...) | e9, 컴퓨터는, 실수를, 내부적으로, 근사적을으로, 관리 |  |

# %% [markdown]
# ### ✅ 진법/비트/입출력
#
# **한줄 정의:** 10진수 -> 다른 진수로 변환 - 원하는 다른 진법의 수로 나눈 뒤 나머지를 거꾸로 읽음 ![alt text](data:image/png;base64,...) 16진수와 2진수 변환 - 2진수, 10진수간 변환은 연산이 많으나, 2진수, 16진수간 변환은 연산이 없음 - 진법 변환을 빠르게 할 수 있으려면 우측 진수 표를 암기하는 것을 권장함 ![alt text](data:image/png;base64,...) 16진수 0xF9를 2진수로 변환해보기 - 정답 = 1111 1001 16진수 0xBB3를 2진수로 변환해보기 - 정답 = 1011 1011 0011 2진수 1100101111를 16진수로 변환해보기 - 먼저 네 자리씩 끊어주기 - 11 0010 1111 - 정답 : 0x32F 비트와 바이트 - 1 bit : 0 과 1을 표현하는 정보의 단위 - 1 byte : 8-bit를 묶어 1 Byte라고 함 (메모리 주소가 부여되는 단위) - 예시 - 1001011011011100 은 총 몇 비트이면서, 몇 바이트 인가?
#
# **핵심 3줄**
# - 사람이 사용하는 사칙연산(+, *, /, -)이 아닌 컴퓨터가 사용하는 연산인 '비트 연산'을 이해해봅니다.
# - 컴퓨터의 CPU 내부적으로 비트 연산을 사용하여 덧셈, 뺄셈, 곱셈 들을 계산함
# - 진법 변환을 빠르게 할 수 있으려면 우측 진수 표를 암기하는 것을 권장함
#
# **짧은 예시:** 예) 13(10진)=1101(2진), 16진수 한 자리는 4비트
#
# **체크포인트/주의:** ‘조건/제약’을 먼저 확인하고, 최악 케이스(시간초과)까지 체크하면 안정적이에요.
#
# **키워드:** `비트`, `연산`, `alt`, `text`, `data`, `image`
#
# 🖼️ **관련 이미지**
#
# ![alt text](data:image/png;base64,...)
#
# ![alt text](data:image/png;base64,...)
#
# ![alt text](data:image/png;base64,...)
#
# *(이미지는 기억을 돕는 시각 단서로 붙였어요.)*
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 10진수 -> 다른 진수로 변환
#
# - 원하는 다른 진법의 수로 나눈 뒤 나머지를 거꾸로 읽음
#
# ![alt text](data:image/png;base64,...)
#
# #### 16진수와 2진수 변환
#
# - 2진수, 10진수간 변환은 연산이 많으나, 2진수, 16진수간 변환은 연산이 없음
# - 진법 변환을 빠르게 할 수 있으려면 우측 진수 표를 암기하는 것을 권장함
#
# ![alt text](data:image/png;base64,...)
#
# #### 16진수 0xF9를 2진수로 변환해보기
#
# - 정답 = 1111 1001
#
# #### 16진수 0xBB3를 2진수로 변환해보기
#
# - 정답 = 1011 1011 0011
#
# #### 2진수 1100101111를 16진수로 변환해보기
#
# - 먼저 네 자리씩 끊어주기
# - 11 0010 1111
# - 정답 : 0x32F
#
# #### 비트와 바이트
#
# - 1 bit : 0 과 1을 표현하는 정보의 단위
# - 1 byte : 8-bit를 묶어 1 Byte라고 함 (메모리 주소가 부여되는 단위)
#
# - 예시
#   - 1001011011011100 은 총 몇 비트이면서, 몇 바이트 인가?
#
# #### 비트 연산
#
# - 컴퓨터의 CPU 내부적으로 비트 연산을 사용하여 덧셈, 뺄셈, 곱셈 들을 계산함
#
# - 비트 연산 챕터의 목적
#   - 사람이 사용하는 사칙연산(+, *, /, -)이 아닌 컴퓨터가 사용하는 연산인 '비트 연산'을 이해해봅니다.
#   - 더 나아가, 프로그래밍에서 비트연산을 활용한 코딩 방법을 익혀봅니다.
#
# #### 비트 연산 AND와 OR 이해하기
#
# - a AND b : a, b 둘 다 1 일 때만 결과가 1, 그 외에는 0
# - a OR b : a, b 둘 중 하나만 1 이면 결과가 1, 그 외에는 0
#
# ![alt text](data:image/png;base64,...)
#
# #### 파이썬에서 2진수, 16진수, 10진수 변환하여 출력하기
#
# - 2진수는 숫자 0과 소문자 b -> 0b를 접두사로 붙여 표현합니다.
# - 16진수는 숫자 0과 소문자 x -> 0x를 접두사로 붙여 표현합니다.
#
# ![alt text](data:image/png;base64,...)
#
# #### 비트 XOR 연산자
#
# - ^: XOR(Exclusive-OR)연산자, 둘 다 1이거나 0인 경우는 0이다.
#
# ![alt text](data:image/png;base64,...)
#
# #### 비트 연산 응용 1
#
# - 1 << n
# - 2^n 의 값을 갖습니다.
# - 임베디드 분야에서 계산을 빠르게 하기 위해 사용
#
# #### 비트 연산 응용 2
#
# - i & (1 << n)
#   - i의 n번째 비트가 1인지 아닌지를 확인할 수 있다.
#
# #### bitwise NOT (complement) 연산자
#
# - ~연산자 : 모든 비트를 반전시킴
# - 만약 8-bit 일 때 ~(0001 111)이라면 값은 1110 0000 이 됨
#
# #### bitwise NOT 연산자를 파이썬에서 수행하기
#
# - 파이썬에서는 ~4 를 수행하면 -5가 출력됨
# - 파이썬이 ~4를 -5로 출력하는 과정
#   - 4는 0b0100입니다. (MSB : 양수이므로 0)
#   - NOT 연산자로 인해 뒤집으면 1011이 됩니다.
#   - MSB는 1이 되었고 (음수), 나머지 bit는 011입니다.
#   - 나머지 bit에 대해 2의 보수를 취하면 100 + 1 = 101이므로 5가 됩니다.
#   - 따라서 -5가 됩니다.
#
# </details>

# %% [markdown]
# ### ✅ 10 진수 -> 2 진수로 변환 구현
#
# **한줄 정의:** 10 진수 -> 2 진수로 변환 구현 - 10진수를 지속적으로 2로 나누어 구현 - 마지막으로 List를 거꾸로 뒤집기
#
# **핵심 3줄**
# - 10진수를 지속적으로 2로 나누어 구현
# - 마지막으로 List를 거꾸로 뒤집기
#
# **짧은 예시:** 예) 이해→재정의→계획→검증(엣지/복잡도)→구현
#
# **체크포인트/주의:** ‘조건/제약’을 먼저 확인하고, 최악 케이스(시간초과)까지 체크하면 안정적이에요.
#
# **키워드:** `구현`, `진수`, `진수로`, `변환`, `10진수를`, `지속적으로`
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 10 진수 -> 2 진수로 변환 구현
#
# - 10진수를 지속적으로 2로 나누어 구현
# - 마지막으로 List를 거꾸로 뒤집기
#
# </details>

# %% [markdown]
# ### ✅ 2 진수를 10 진수로 변환
#
# **한줄 정의:** 2 진수를 10 진수로 변환 ![alt text](data:image/png;base64,...)
#
# **핵심 3줄**
#
# **짧은 예시:** 예) 이해→재정의→계획→검증(엣지/복잡도)→구현
#
# **체크포인트/주의:** ‘조건/제약’을 먼저 확인하고, 최악 케이스(시간초과)까지 체크하면 안정적이에요.
#
# **키워드:** `Hee`, `eg`, `Hrr7`, `j7`, `H4`, `진수를`
#
# 🖼️ **관련 이미지**
#
# ![alt text](data:image/png;base64,...)
#
# *(이미지는 기억을 돕는 시각 단서로 붙였어요.)*
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 2 진수를 10 진수로 변환
#
# ![alt text](data:image/png;base64,...)
#
# </details>

# %% [markdown]
# ### ✅ 파이썬 구현
#
# **한줄 정의:** 파이썬 구현 - 7 & 5 -> 이진수로 표현하면 0b11 & 0b101 ![alt text](data:image/png;base64,...)
#
# **핵심 3줄**
# - 7 & 5 -> 이진수로 표현하면 0b11 & 0b101
#
# **짧은 예시:** 예) 이해→재정의→계획→검증(엣지/복잡도)→구현
#
# **체크포인트/주의:** ‘조건/제약’을 먼저 확인하고, 최악 케이스(시간초과)까지 체크하면 안정적이에요.
#
# **키워드:** `bdd1`, `O9`, `9re`, `POf`, `Pz`, `파이썬`
#
# 🖼️ **관련 이미지**
#
# ![alt text](data:image/png;base64,...)
#
# *(이미지는 기억을 돕는 시각 단서로 붙였어요.)*
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 파이썬 구현
#
# - 7 & 5 -> 이진수로 표현하면 0b11 & 0b101
#
# ![alt text](data:image/png;base64,...)
#
# </details>

# %% [markdown]
# ### ✅ 신기한 XOR
#
# **한줄 정의:** 신기한 XOR - 어떤 값이던 특정 수로 2회 XOR를 하면 원래 수로 돌아옴
#
# **핵심 3줄**
# - 어떤 값이던 특정 수로 2회 XOR를 하면 원래 수로 돌아옴
#
# **짧은 예시:** 예) 이해→재정의→계획→검증(엣지/복잡도)→구현
#
# **체크포인트/주의:** ‘조건/제약’을 먼저 확인하고, 최악 케이스(시간초과)까지 체크하면 안정적이에요.
#
# **키워드:** `수로`, `신기한`, `XOR`, `어떤`, `값이던`, `특정`
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 신기한 XOR
#
# - 어떤 값이던 특정 수로 2회 XOR를 하면 원래 수로 돌아옴
#
# </details>

# %% [markdown]
# ### ✅ 암호화에 사용되는 XOR
#
# **한줄 정의:** 암호화에 사용되는 XOR - 친구 1과 친구2는 서로 비밀코드를 1004로 약속 ![alt text](data:image/png;base64,...)
#
# **핵심 3줄**
# - 친구 1과 친구2는 서로 비밀코드를 1004로 약속
#
# **짧은 예시:** 예) 이해→재정의→계획→검증(엣지/복잡도)→구현
#
# **체크포인트/주의:** ‘조건/제약’을 먼저 확인하고, 최악 케이스(시간초과)까지 체크하면 안정적이에요.
#
# **키워드:** `Hw`, `P1`, `n4`, `H5`, `c9`, `fz`
#
# 🖼️ **관련 이미지**
#
# ![alt text](data:image/png;base64,...)
#
# *(이미지는 기억을 돕는 시각 단서로 붙였어요.)*
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 암호화에 사용되는 XOR
#
# - 친구 1과 친구2는 서로 비밀코드를 1004로 약속
#
# ![alt text](data:image/png;base64,...)
#
# </details>

# %% [markdown]
# ### ✅ 쉬프트 연산자
#
# **한줄 정의:** 쉬프트 연산자 - Left Shift << : 특정 수 만큼 비트를 왼쪽으로 밀어냄 - Right Shift >> : 특정 수 만큼 비트를 오른쪽으로 밀어냄 (우측 비트들이 제거됨) ![alt text](data:image/png;base64,...)
#
# **핵심 3줄**
# - Right Shift >> : 특정 수 만큼 비트를 오른쪽으로 밀어냄 (우측 비트들이 제거됨)
# - Left Shift << : 특정 수 만큼 비트를 왼쪽으로 밀어냄
#
# **짧은 예시:** 예) 13(10진)=1101(2진), 16진수 한 자리는 4비트
#
# **체크포인트/주의:** ‘조건/제약’을 먼저 확인하고, 최악 케이스(시간초과)까지 체크하면 안정적이에요.
#
# **키워드:** `Pz`, `v7`, `9e`, `Shift`, `특정`, `만큼`
#
# 🖼️ **관련 이미지**
#
# ![alt text](data:image/png;base64,...)
#
# *(이미지는 기억을 돕는 시각 단서로 붙였어요.)*
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 쉬프트 연산자
#
# - Left Shift << : 특정 수 만큼 비트를 왼쪽으로 밀어냄
# - Right Shift >> : 특정 수 만큼 비트를 오른쪽으로 밀어냄 (우측 비트들이 제거됨)
#
# ![alt text](data:image/png;base64,...)
#
# </details>

# %% [markdown]
# ### ✅ 음수 표현 방법
#
# **한줄 정의:** 음수 표현 방법 - 컴퓨터는 음수를 "2의 보수"로 관리함 맨 앞자리 - 맨 앞자리 bit(MSB)는 음수 or 양수를 구분하는 비트임 - 2의 보수: 각 비트를 뒤집는다 -> +1을 진행 - 컴퓨터가 2의 보수를 사용하여 음수를 관리하는 이유 - 뺄셈의 연산 속도를 올릴 수 있으며, +0과 -0을 따로 취급하지 않기 위해 사용합니다.
#
# **핵심 3줄**
# - 맨 앞자리 bit(MSB)는 음수 or 양수를 구분하는 비트임
# - 2의 보수: 각 비트를 뒤집는다 -> +1을 진행
# - 뺄셈의 연산 속도를 올릴 수 있으며, +0과 -0을 따로 취급하지 않기 위해 사용합니다.
#
# **짧은 예시:** 예) 13(10진)=1101(2진), 16진수 한 자리는 4비트
#
# **체크포인트/주의:** ‘조건/제약’을 먼저 확인하고, 최악 케이스(시간초과)까지 체크하면 안정적이에요.
#
# **키워드:** `2의`, `음수`, `음수를`, `보수`, `앞자리`, `표현`
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 음수 표현 방법
#
# - 컴퓨터는 음수를 "2의 보수"로 관리함 맨 앞자리
#   - 맨 앞자리 bit(MSB)는 음수 or 양수를 구분하는 비트임
#   - 2의 보수: 각 비트를 뒤집는다 -> +1을 진행
# - 컴퓨터가 2의 보수를 사용하여 음수를 관리하는 이유
#   - 뺄셈의 연산 속도를 올릴 수 있으며, +0과 -0을 따로 취급하지 않기 위해 사용합니다.
#
# </details>

# %% [markdown]
# ### ✅ 2의 보수 예시
#
# **한줄 정의:** 2의 보수 예시 - 10001의 2의 보수 - 수를 모두 뒤집고 1을 더합니다
#
# **핵심 3줄**
# - 수를 뒤집으면 0000111이고 1을 더합니다.
# - 0000111 + 1 = 0001000
# - 수를 모두 뒤집고 1을 더합니다.
#
# **짧은 예시:** 예) 이해→재정의→계획→검증(엣지/복잡도)→구현
#
# **체크포인트/주의:** ‘조건/제약’을 먼저 확인하고, 최악 케이스(시간초과)까지 체크하면 안정적이에요.
#
# **키워드:** `2의`, `보수`, `수를`, `1을`, `더합니다`, `예시`
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 2의 보수 예시
#
# - 10001의 2의 보수
#   - 수를 모두 뒤집고 1을 더합니다.
#   - 01110 + 1 = 01111
# - 1111000의 2의 보수
#   - 수를 뒤집으면 0000111이고 1을 더합니다.
#   - 0000111 + 1 = 0001000
#
# </details>

# %% [markdown]
# ### ✅ 신기한 2의 보수
#
# **한줄 정의:** 신기한 2의 보수 - 2의 보수를 취한 수를, 한번 더 2의 보수를 취하면 윈래의 값으로 돌아옴 - 10001의 2의 보수 - 수를 모두 뒤집고 1을 더합니다
#
# **핵심 3줄**
# - 수 5를 뒤집으면 111 1010 이며, 1을 더하면 111 1011이 됨
# - 2의 보수를 취한 수를, 한번 더 2의 보수를 취하면 윈래의 값으로 돌아옴
# - 5를 2의 보수로 표현하는 방법 (가정 : 수를 8-bit로 저장하는 경우)
#
# **짧은 예시:** 예) 13(10진)=1101(2진), 16진수 한 자리는 4비트
#
# **체크포인트/주의:** ‘조건/제약’을 먼저 확인하고, 최악 케이스(시간초과)까지 체크하면 안정적이에요.
#
# **키워드:** `2의`, `보수`, `수를`, `1을`, `5를`, `x5`
#
# 🖼️ **관련 이미지**
#
# ![alt text](data:image/png;base64,...)
#
# *(이미지는 기억을 돕는 시각 단서로 붙였어요.)*
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 신기한 2의 보수
#
# - 2의 보수를 취한 수를, 한번 더 2의 보수를 취하면 윈래의 값으로 돌아옴
# - 10001의 2의 보수
#   - 수를 모두 뒤집고 1을 더합니다.
#   - 01110 + 1 = 0111
# - 01111의 2의 보수
#   - 10000 + 1 = 10001
#
# -5를 2의 보수로 표현하는 방법 (가정 : 수를 8-bit로 저장하는 경우)
# -   수 5를 2진수로 나타내면 0000 0101 (7bit)
# -   -5는 음수이기에 MSB는 1
# -   나머지 7-bit에 대해, 수를 뒤집고 1을 더함 (2의 보수)
# -   수 5를 뒤집으면 111 1010 이며, 1을 더하면 111 1011이 됨
# -   따라서 1111 1011이 됨
#
# ![alt text](data:image/png;base64,...)
#
# </details>

# %% [markdown]
# ### ✅ 파이썬에서 실수 출력 방법
#
# **한줄 정의:** 파이썬에서 실수 출력 방법 - 파이썬은 f-string 문법을 지향
#
# **핵심 3줄**
# - 파이썬은 f-string 문법을 지향
#
# **짧은 예시:** 예) 이해→재정의→계획→검증(엣지/복잡도)→구현
#
# **체크포인트/주의:** #### 파이썬에서 실수 출력 방법
#
# **키워드:** `파이썬에서`, `실수`, `출력`, `파이썬은`, `string`, `문법을`
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 파이썬에서 실수 출력 방법
#
# - 파이썬은 f-string 문법을 지향
#
# </details>

# %% [markdown]
# ### ✅ 소수점 출력 방법
#
# **한줄 정의:** 소수점 출력 방법 - {t2:.2f} : t2값을 소수점 셋째자리에서 반올림하여 표현
#
# **핵심 3줄**
# - {t2:.2f} : t2값을 소수점 셋째자리에서 반올림하여 표현
#
# **짧은 예시:** 예) 이해→재정의→계획→검증(엣지/복잡도)→구현
#
# **체크포인트/주의:** ‘조건/제약’을 먼저 확인하고, 최악 케이스(시간초과)까지 체크하면 안정적이에요.
#
# **키워드:** `소수점`, `출력`, `t2`, `2f`, `t2값을`, `셋째자리에서`
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 소수점 출력 방법
#
# - {t2:.2f} : t2값을 소수점 셋째자리에서 반올림하여 표현
#
# </details>

# %% [markdown]
# ### ✅ 파이썬에서의 실수 표현 범위
#
# **한줄 정의:** 파이썬에서의 실수 표현 범위 - 파이썬에서는 64비트 부동소수점으로 실수를 표현함 - 15~17자리 정밀도와 +- 1.8e308 범위를 갖습니다
#
# **핵심 3줄**
# - 파이썬에서는 64비트 부동소수점으로 실수를 표현함
# - 최대로 표현할 수 있는 값은 약 1.8 x 10^308 이고 이 이상은 inf로 표현 (참고로 1억은 1 x 10^8임)
# - 최소로 표현할 수 있는 (0에 가장 가까운) 값은 약 5.0 x 10^-324이며, 이 이하는 0으로 표현
#
# **짧은 예시:** 예) 13(10진)=1101(2진), 16진수 한 자리는 4비트
#
# **체크포인트/주의:** #### 파이썬에서의 실수 표현 범위
#
# **키워드:** `표현`, `표현할`, `있는`, `값은`, `파이썬에서의`, `실수`
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 파이썬에서의 실수 표현 범위
#
# - 파이썬에서는 64비트 부동소수점으로 실수를 표현함
#   - 15~17자리 정밀도와 +- 1.8e308 범위를 갖습니다.
# - 최대로 표현할 수 있는 값은 약 1.8 x 10^308 이고 이 이상은 inf로 표현 (참고로 1억은 1 x 10^8임)
# - 최소로 표현할 수 있는 (0에 가장 가까운) 값은 약 5.0 x 10^-324이며, 이 이하는 0으로 표현
#
# </details>

# %% [markdown]
# ### ✅ 컴퓨터는 실수를 내부적으로 근사적을으로 관리
#
# **한줄 정의:** 컴퓨터는 실수를 내부적으로 근사적을으로 관리 - 실수는 정확한 값이 아니라 근사 값으로 저장되는데 이때 생기는 작은 오차가 계산 과정에서 다른 결과를 가져옴 ![alt text](data:image/png;base64,...)
#
# **핵심 3줄**
# - 실수는 정확한 값이 아니라 근사 값으로 저장되는데 이때 생기는 작은 오차가 계산 과정에서 다른 결과를 가져옴
#
# **짧은 예시:** 예) 이해→재정의→계획→검증(엣지/복잡도)→구현
#
# **체크포인트/주의:** #### 컴퓨터는 실수를 내부적으로 근사적을으로 관리
#
# **키워드:** `e9`, `컴퓨터는`, `실수를`, `내부적으로`, `근사적을으로`, `관리`
#
# 🖼️ **관련 이미지**
#
# ![alt text](data:image/png;base64,...)
#
# *(이미지는 기억을 돕는 시각 단서로 붙였어요.)*
#
# <details>
# <summary>자세히(원문/상세) 펼치기</summary>
#
# #### 컴퓨터는 실수를 내부적으로 근사적을으로 관리
#
# - 실수는 정확한 값이 아니라 근사 값으로 저장되는데 이때 생기는 작은 오차가 계산 과정에서 다른 결과를 가져옴
#
# ![alt text](data:image/png;base64,...)
#
# </details>

# %% [markdown]
# ## 4. 풀이 전략
#
# 1) 문제 읽고 이해(조건/입출력/제약)
# 2) 재정의(내 언어로 다시 쓰기)
# 3) 계획(자료구조/알고리즘 후보)
# 4) 검증(엣지 + 최악 케이스 복잡도)
# 5) 구현 후 케이스 바꿔가며 테스트(파일입력 활용)

# %% [markdown]
# ## 6. 구현(원본 코드 유지)
#
# 아래는 원본 코드 셀을 최대한 그대로 유지했어요. 입력이 필요한 코드는 예시 실행 셀을 추가했어요.

# %% [markdown]
# ### 6-1) 10 진수 -> 2 진수로 변환 구현

# %%
# 10진수를 2진수로 변환
def decimal_to_binary(n):
    binary_number = ''

    if n == 0:
        return '0'
    
    # 1.0보다 클 때까지 2로 나누면서(반복을 끝내는 조건)
    # 2.나머지를 정답에 추가(추가구현)
    while n > 0:
        # 2로 나눈 나머지를 구해서
        remain = n % 2
        # 정답에 추가
        binary_number = str(remain) + binary_number

        # 2로 나눈다.
        n = n // 2
    
    return binary_number

print(decimal_to_binary(25))

# %% [markdown]
# ### 6-2) 16진수와 2진수 변환

# %%
# 10진수를 16진수로 변환
def decimal_to_hexadecimal(n):
    hex_digits = '0123456789ABCDEFG'
    hexadecimal_number = ''

    while n > 0:
        remain = n % 16
        hexadecimal_number = hex_digits[remain] + hexadecimal_number

        n = n // 16

    return hexadecimal_number

print(decimal_to_hexadecimal(255))

# 내장함수가 있기는 하다(직접 구하는 연습)
print(bin(5))
print(hex(255))

# %% [markdown]
# ### 6-3) 암호화에 사용되는 XOR

# %%
secret_code = 1004

print(7070 ^ secret_code)
print(6258 ^ secret_code)

# %% [markdown]
# ### 6-4) 비트 연산 응용 1

# %%
# 비트 연산 응용

# 1. 1 << n -> 2 ^ n 을 구할 수 있다.
# - 부분 집합의 수를 바로 계산할 수 있다.
arr = [7, 1, 3, 5]

print(f'부분 집합의 수 : {1 << len(arr)}개')

# 2. 전체 부분 집합을 구할 수 있다.
# i = 부분집합 번호
for i in range(1 << len(arr)):
    print(f'{i}번 째 부분집합:', end=' ')

    # 각 자리수를 모두 확인
    for idx in range(len(arr)):
        if i & (1 << idx):
            print(arr[idx], end=' ')
            
    print()

# %% [markdown]
# ### 6-5) 음수 표현 방법

# %%
def bit_print(i):
    output = ''
    for j in range(7, -1, -1):
        output += '1' if i & (1 << j) else '0'

for i in range(-5, 6):
    print(f'{i} = ', end='')
    bit_print(i)

# %% [markdown]
# ### 6-6) ## 실수

# %%
t1 = 10
t2 = 3.141592

print(f'변수 값은 {t1} 입니다')
print(f'변수 값은 {t2} 입니다')

# %% [markdown]
# ### 6-7) 소수점 출력 방법

# %%
t1 = 10
t2 = 3.141592

print(f'변수 값은 {t1} 입니다')
print(f'변수 값은 {t2:.2f} 입니다')

# %% [markdown]
# ## 7. 테스트 + 자주하는 실수(엣지 케이스 포함)
#
# - 히든 테스트케이스는 보통 **엣지케이스** + **최악케이스(시간초과 유발)**
# - 제약 확인 누락, 출력 형식 실수, 예외조건(0/1/빈/최대) 누락이 자주 나옴
#
# ✅ 체크리스트: `엣지 2개` + `최악 1개` + `랜덤 1개`

# %% [markdown]
# ## 8. 복잡도
#
# - 반복문: 총 반복 횟수 × 1회 비용
# - 중첩 반복: 바깥×안쪽
# - 입력이 커질수록 차이가 커짐 → O(N^2) vs O(N log N)

# %% [markdown]
# ## 9. 요약 + 미니 퀴즈
#
# ### 🧷 요약
# - 핵심은 **과정(이해→재정의→계획→검증)** + **검증 루틴(엣지/복잡도)**
#
# ### 🎯 미니 퀴즈
# 1) 검증에서 꼭 확인해야 하는 2가지는?
# 2) 히든 테스트케이스가 주로 노리는 유형은?
# 3) 완전탐색이 막히면 다음 후보는?
# 4) O(N)과 O(N^2)의 차이는?
# 5) 16진수 한 자리는 몇 비트?
