# %% [markdown]
# sw 문제해결
#
# sw 문제해결 역량이란?
# - 프로그램을 하기 위한 많은 제약 조건과 요구 사항을 이해하고 최선의 방법을 찾아내는 능력
# - 프로그래머가 사용하는 언어나 라이브러리, 자료구조, 알고리즘에 대한 지식을 적재적소에 퍼즐을 배치하듯 이들을 연결하여 큰 그림을 만드는 능력이라 할 수 있음
# - 문제해결 역량은 추상적인 기술임
#   - 프로그래밍 언어, 알고리즘처럼 명확히 정의된 실체가 없습니다.
#   - 무작정 알고리즘을 암기하고 문제를 풀어본다고 향상되지 않습니다.
# - **문제해결 역량을 향상시키기 위해서 훈련이 필요함**
#
# 문제해결 과정 **중요**
# 1. 문제를 읽고 이해한다.
# 2. 문제를 익숙한 용어로 재정의한다. (나만의 언어 => 문제를 제대로 이해하기 위해)
# 3. 어떻게 해결할지 계획을 세운다. (자료구조, 알고리즘은 어떤게 있는가 생각)
# 4. 계획을 검증한다. (**검증이 매우 중요하다**, 복잡도 계산)
# 5. 프로그램을 구현한다.
# 6. 어떻게 풀었는지 돌아보고, 개선할 방법이 있는지 찾아본다.
# **1 ~ 4 과정이 훈련되어야 한다.**
#
# 채점: 히든 테스트케이스 있다
# 히든 테스트케이스는 보통 어떤 종류로 만들까?
# - 엣지케이스 (문제에서 숨겨져 있는 조건에 맞는 케이스)
#   - 눈에 바로 보이지 않는 케이스
# - 시간 초과 (최악의 케이스)
#
# 알고리즘
# - 일단 완전 탐색 (시간 초과)
# - 안된다면 그리디, DP
#
# 자료구조
# - 리스트
# - 딕셔너리
# - set
# - 큐, 스택
# - 트리
# - 이진 탐색
# - 힙
# - 등등등

# %% [markdown]
# 리스트에 숫자 넣기
# - 수 N을 입력 받는다.
# - 윗 줄에는 N부터 1씩 증가되는 숫자 4개를 왼쪽에 채운다.
# - 아랫 줄에는 N부터 1씩 감소되는 숫자 4개를 오른쪽에 채운다.
# - 최종 결과를 출력한다. 빈 공간은 0으로 출력한다.
#
# ![alt text](<스크린샷 2026-03-04 092531.png>)
#
# 자료구조
# - 리스트 (2개 or 이차원)
# 알고리즘
# - 단순 반복
#   - 반복 횟수가 정해져 있네? -> for문

# %% [markdown]
# sw 문제해결 능력을 기르는 이유
# - 코딩을 더 잘하게 하는 능력을 기르기 위함
# - 문제를 통해 기본문법 & 자료구조 & 알고리즘을 더 능숙하게 쓸 수 있도록 훈련함
#
# swea 문제를 잘 풀기 위한 전략
# - 단계 1 : 완벽한 문제 이해
# - 단계 2 : 종이와 펜을 이용한 설계하기 (어떻게 구현할지 계획하기)
# - 단계 3 : 설계한 대로 구현 & 디버깅을 한다.

# %% [markdown]
# 복잡도 분석
#
# 알고리즘이란?
# - 유한한 단계를 통해 문제를 해결하기 위한 절차나 방법
# - 다시 말하면 어떠한 문제를 해결하기 위한 절차라고 볼 수 있음
# - 1부터 100까지의 합을 구하는 두 가지 알고리즘의 예

# %% [markdown]
# 알고리즘의 효율
# - 공간적 효율성과 시간적 효율성
#   - 공간적 효율성은 알고리즘이 필요로 하는 메모리 공간
#   - 시간적 효율성은 알고리즘이 작업을 완료하는 데 걸리는 시간을 말합니다.
#   - 효율성을 뒤집어 표현하면 복잡도(Complexity)가 됩니다. 복잡도가 높을수록 효율성은 저하됩니다.

# %% [markdown]
# 복잡도의 점근적 표기
# - 시간복잡도는 입력 크기에 대한 함수로 표기
#   - 이 함수는 주로 여러 개의 항을 가지는 다항식입니다.
#   - 이를 단순한 함수로 표현하기 위해 점근적 표기(Asymptotic Notation)를 사용합니다.
#
# - 입력 크기 n이 무한대로 커질 때의 복잡도를 간단히 표현하기 위해 사용되는 표기법
#   - (Big-Oh 또는 Big-O) 표기 -> 최악의 케이스
#   - (Big-Omega) 표기
#   - (Big-theta) 표기

# %%
# 아래 코드는 몇 번 반복될까?

n = int(input())

for i in range(n):
    print(i, end='')

# %% [markdown]
# O(Big-Oh) 표기
# - Big-Oh 표기는 복잡도의 점근적 상한을 나타냄
# - 복잡도가 f(n) = 2n^2-7n+4 이라면, O-표기는 O(n^2) (실제 연산 횟수와는 차이가 클 수 있다. 그치만 무한대에 가깝다고 생각하교 표기함)
# - 먼저 f(n)의 단순화된 표현은 n^2
# - 단순화된 함수 n^2에 임의의 상수 c를 곱한 cn^2이 n이 증가함에 따라 f(n)의 상한이 된다. (단 c>0)
#
# ![alt text](<화면 캡처 2026-03-05 005626.jpg>)

# %% [markdown]
# 빅오표기법으로 표현하면?
# - O(n)
# - O(n^2)
# - O(1)

# %% [markdown]
# O(N) vs O(1)
# 뭐가 더 좋은지는 조건에 따라 달라진다

# %% [markdown]
# 빅요표기법 표현 방법
# - O(5N)
#   - 정확한 배수를 강조하고 싶은 경우라면?
#   - 주로 논문등에서 사용

# %% [markdown]
# 빅오표기법으로 성능 비교하기
# - 어떤 알고리즘이 더 좋은 성능을 내는가?
#
# O(N)으로 작성한 알고리즘 VS O(N)으로 작성한 알고리즘
# 경우에 따라 다르다!!

# %% [markdown]
# 자주 사용하는 O- 표기
# - O(1) 상수시간
# - O(logn) 로그(대수) 시간 (ex. 이진탐색)
# - O(n) 선형 시간
# - O(nlogn) 로그 선형 시간
# - O(n^2) 제곱 시간
# - O(n^3) 세제곱 시간

# %% [markdown]
# O(n) 이해하기
# - 만약 N이 10,000 이고 O(N)으로 짠 알고리즘이 있다면, 몇 번 반복하는 프로그램이라고 추정해도 될까?
#   - 정답 : 10,000회
#
# O(n^2) 라면?
# - 만약 N이 10,000 이고 O(N^2)으로 짠 알고리즘이 있다면, 몇 번 반복하는 프로그램이라고 추정해도 될까>
#   - 정답 : 100,000,000회
#
# O(log N) 이라면?
# - 만약 N이 10,000이고 O(log N) 으로 짠 알고리즘이 있다면, 몇 번 반복하는 프로그램이라고 추정해도 될까?
#   - 약 13.3번
# - 컴퓨터 분야에서 log의 밑 수는 10이 아니라 2
#
# 복잡도 비교
# - O(logN) 은 O(1) 보다는 느리지만, N이 작은 경우 유사한 성능
# - O(NlogN) 은 O(N) 보다는 느리지만, N이 작은 경우 유사한 성능
#
# ![alt text](<화면 캡처 2026-03-05 011938.jpg>)
#
# 왜 효율적인 알고리즘이 필요한가?
# - 10억 개의 숫자를 정렬하는데 PC에서 O(n^2) 알고리즘은 300여 년이 걸리는 반면에 O(nlogn) 알고리즘은 5분 만에 정렬함
# - 효율적인 알고리즘은 슈퍼컴퓨터보다 더 큰 가치가 있음
# - 값비싼 HW의 기술 개발보다 효율적인 알고리즘 개발이 훨씬 더 경제적임

# %% [markdown]
# 문제가 몇 초 걸릴까?
# - 알 수 없다
# - 코드를 돌리는 PC 성능에 따라서 다른 시간
#
# 문제풀이 사이트
# - 표준적으로 이 정도 연산이면 몇 초 걸린다 -> 약속을 함
# - 대략 C언어 기준으로 1초당 1억번 정도 가능
# - python 기준으로 대략 3,000 ~ 4,000만번 정도 가능
#
# 14개 테스트케이스를 합쳐서 python의 경우 3초
# - 한 케이스당 대략 6,000,000 횟수 안에 가능하면 무조건 통과 (14개의 테스트 케이스가 최악의 경우라면)
# - 문제를 풀 때 해당 횟수 안에 들어오도록 구현
#
# 자료구조
# - 탐색
# - 삽입
# - 삭제
# - 수정
# 자료구조마다 각 장, 단점 (이진트리: 탐색, 삽입, 삭제)
#
# A형 역량테스트
# - 구현 + 디버깅
#
# B형 역량테스트
# - 자료구조 + 알고리즘 적용
#
# 시간 복잡도
# - 대략적인 시간을 빅-오 표기법으로 표시
# - 실제 연산 횟수도 같이 계산을 해야한다
#   - 문제 풀이에 활용하기 위해서
#   - python 기준으로 1초 당 3천만번 정도 연산이 가능하구나
#
# 공간 복잡도
# - python 의 경우 명확한 계산이 어렵다.
#   - 변수 하나도 많은 메모리를 차지
#   - 동적 메모리는 어느 순간 2배로 계산
#     - 메모리와 시간이 많이 낭비
#
# - 어쩔 수 없는 경우를 제외하고 append 사용을 최대한 피하자
#
# - pypy vs python
#   - pypy: 시간 - 빠름 / 메모리 - 비효율
#     - 재귀호출
#   - python3: 시간 - 느림/ 메모리 -효율

# %% [markdown]
# 표준 입출력 방법
#
# 챕터의 목표 : 콘솔 입력 대신, 파일입력
#
# 테스트케이스를 바꾸면서 테스트 가능

# %% [markdown]
# 진법
#
# 2진수, 8진수, 10진수, 16진수
# - 10진수: 사람이 사용하는 진수, 수 하나를 0~9로 표현
# - 2진수: 컴퓨터가 사용하는 진수, 수 하나를 0, 1로 표현
# - 8진수: 2진수를 더 가독성 있게 사용
# - 16진수: 2진수를 더 가독성 있게 사용, 수 하나를 0, 1, ... , 8, 9, A, B, C...로 표현

# %% [markdown]
# 왜 16진수를 사용하는 것인가?
# - 2 진수를 사람이 이해하기 편하도록, 10 진수를 변환 시
#   - 인간이 이해하기 편하지만, 연산이 오래 걸림
# - 2 진수를 사람이 이해하기 편하도록, 16진수로 변환 시
#   - 인간이 이해하기 어렵지만, 연산 속도가 매우 빠름

# %% [markdown]
# 우리는 어떻게 활용하려고 배울까?
# 2진수 -> 비트로 표현 가능 -> 비트연산 가능

# %% [markdown]
# 진법 변환
#
# 10진수 -> 다른 진수로 변환
# - 원하는 다른 진법의 수로 나눈 뒤 나머지를 거꾸로 읽음
# - 코드로 구현
#   - while
#   - 재귀

# %%
# 십진수를 이진수로

decimal = 149

# 십진수를 이진수로 바꾼 결과
binary = 0

# 2로 나눈 몫이 2보다 작아질때까지 계속 나눈다
# 나머지를 거꾸로 읽으면 이진수 완성

# 중간 나눗셈에서 나머지를 기억할 배열
arr = []

while decimal != 0:
    arr.append(decimal % 2)
    # 다음에 나눌 숫자는 2로 나눈 몫
    decimal = decimal // 2

arr.reverse()
print(*arr)


# 비트연산자
def bit_print(dec):
    # dec을 2진수로 만든 결과
    output = ""

    for i in range(7, -1, -1):
        if dec & (1 << i):
            output += "1"
        else:
            output += "0"

    return output


print(bit_print(149))

# %%
# 16진수

hex_to_bin = {
    "0": "0000", "1": "0001", "2": "0010", "3": "0011", "4": "0100", "5": "0101", "6": "0110",
    "7": "0111", "8": "1000", "9": "1001", "A": "1010", "B": "1011", "C": "1100", "D": "1101",
    "E": "1110", "F": "1111"
}

hex = "47FE"

result = ""
for i in range(4):
    result += hex_to_bin[hex[i]]

print(result)

result2 = ""
for c in hex:
    # c를 숫자로 바꾸고
    dec = int(c, 16)

    result_bin = ""

    # 2진수 * 4
    for i in range(3, -1, -1):
        result_bin += "1" if dec & (1 << i) else "0"

    result2 += result_bin

print(result2)

# %%
# 연습문제

bit = "00000010001101"

# 이진수를 7칸씩 쪼개서 쪼갠 것들 각각 십진수로 바꾸기
N = len(bit)

# 길이가 14
# 0~6
# 7~13
for i in range(0, N, 7):
    # i번 비트에서 7칸 잘라서 십진수로 만들고 출력
    ith_bin = bit[i:i + 7]

    decimal = 0

    # ex) bin = 0000001
    # decimal += bin[6] * 2**0
    # decimal += bin[5] * 2**1
    # decimal += bin[4] * 2**2
    # ..
    # decimal += bin[0] * 2**6
    for j in range(6, -1, -1):
        decimal += int(ith_bin[j]) * 2 ** (6 - j)

    print(decimal, ",")
